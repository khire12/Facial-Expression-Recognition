# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import dlib
import pickle
import h5py
import cv2
import scipy

# %%
# %tensorflow_version 2.x
import tensorflow as tf

# %%
dataset = pd.read_csv('/content/drive/My Drive/Datasets/fer2013.csv')

# %%
def get_images(usage):
  df = dataset[dataset['Usage'] == usage]
  y = tf.keras.utils.to_categorical(df['emotion'])
  X = np.array([values.split() for values in df['pixels']])
  X = X.astype(np.float).reshape(len(df), 48, 48, 1)
  return (X, y)

# %%
X_train, y_train = get_images('Training')
X_test, y_test =  get_images('PublicTest')
X_validate, y_validate = get_images('PrivateTest')

# %%
print('X_train:', X_train.shape)
print('y_train:', y_train.shape)

print('X_test:', X_test.shape)
print('y_test:', y_test.shape)

print('X_validate:', X_validate.shape)
print('y_validate:', y_validate.shape)
# Out:
# X_train: (28709, 48, 48, 1)
# y_train: (28709, 7)
# X_test: (3589, 48, 48, 1)
# y_test: (3589, 7)
# X_validate: (3589, 48, 48, 1)
# y_validate: (3589, 7)

# %%
train_data = X_train.astype('float32')
test_data = X_test.astype('float32')
val_data = X_validate.astype('float32')

train_data /= 255
test_data /= 255
val_data /= 255

# %%
def get_label(arg):
  labels = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Sad',5:'Surprise',6:'Neutral'}
  return (labels.get(arg,"Invalid Emotion"))

# %%
shape_x = 48
shape_y = 48

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Conv2D(64, (3,3),padding="same", activation='swish', input_shape=(48, 48, 1),  data_format='channels_last',kernel_regularizer=tf.keras.regularizers.l2(0.01)),
  
  tf.keras.layers.Conv2D(64, kernel_size=(3, 3), activation='swish', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2,2)),
  tf.keras.layers.Dropout(0.5),
  
  tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation='swish', padding='same'),
  tf.keras.layers.BatchNormalization(),
  
  tf.keras.layers.Conv2D(128, kernel_size=(3, 3), activation='swish', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2,2)),
  tf.keras.layers.Dropout(0.5),

  tf.keras.layers.Conv2D(256, kernel_size=(3, 3), activation='swish', padding='same'),
  tf.keras.layers.BatchNormalization(),
  
  tf.keras.layers.Conv2D(256, kernel_size=(3, 3), activation='swish', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2,2)),
  tf.keras.layers.Dropout(0.5),

  tf.keras.layers.Conv2D(512, kernel_size=(3, 3), activation='swish', padding='same'),
  tf.keras.layers.BatchNormalization(),
  
  tf.keras.layers.Conv2D(512, kernel_size=(3, 3), activation='swish', padding='same'),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2,2)),
  tf.keras.layers.Dropout(0.5),

  tf.keras.layers.Flatten(),

  tf.keras.layers.Dense(512, activation='swish'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(256, activation='swish'),
  tf.keras.layers.Dropout(0.4),
  tf.keras.layers.Dense(128, activation='swish'),
  tf.keras.layers.Dropout(0.5),

  tf.keras.layers.Dense(7, activation = 'softmax')
  ])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# batch_normalization (BatchNo (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 128)       73856
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 256)       295168
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 256)       590080
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 256)       1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 512)         1180160
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 512)         2359808
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2359808
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 7,216,583
# Trainable params: 7,212,871
# Non-trainable params: 3,712
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, to_file='model_fer.png', show_shapes=True, show_layer_names=True)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
lr_reducer_d = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.7, patience=10, verbose=1)

tensorboard_d = tf.keras.callbacks.TensorBoard(log_dir='./logs')

early_stopper_d = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=40, verbose=1, mode='auto')

checkpointer_d = tf.keras.callbacks.ModelCheckpoint('model_fer.h5', monitor='val_loss', verbose=1, save_best_only=True)

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    zoom_range=0.1,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False,
)

# %%
history = model.fit(
    datagen.flow(train_data, y_train, batch_size=256),
    steps_per_epoch=int(np.ceil(X_train.shape[0] / float(256))),
    epochs = 200,
    shuffle=True, 
    validation_data=(val_data, y_validate),
    callbacks=[lr_reducer_d, tensorboard_d, early_stopper_d, checkpointer_d]
)
# Out:
# Epoch 1/200
# 113/113 [==============================] - ETA: 0s - loss: 2.0954 - accuracy: 0.2046
# Epoch 00001: val_loss improved from inf to 1.86664, saving model to model_fer.h5
# 113/113 [==============================] - 24s 210ms/step - loss: 2.0954 - accuracy: 0.2046 - val_loss: 1.8666 - val_accuracy: 0.2449 - lr: 0.0010
# Epoch 2/200
# 113/113 [==============================] - ETA: 0s - loss: 1.8471 - accuracy: 0.2350
# Epoch 00002: val_loss improved from 1.86664 to 1.83624, saving model to model_fer.h5
# 113/113 [==============================] - 22s 198ms/step - loss: 1.8471 - accuracy: 0.2350 - val_loss: 1.8362 - val_accuracy: 0.2449 - lr: 0.0010
# Epoch 3/200
# 113/113 [==============================] - ETA: 0s - loss: 1.8201 - accuracy: 0.2494
# Epoch 00003: val_loss improved from 1.83624 to 1.82580, saving model to model_fer.h5
# 113/113 [==============================] - 22s 199ms/step - loss: 1.8201 - accuracy: 0.2494 - val_loss: 1.8258 - val_accuracy: 0.2449 - lr: 0.0010
# Epoch 4/200
# 113/113 [==============================] - ETA: 0s - loss: 1.7970 - accuracy: 0.2569
# Epoch 00004: val_loss improved from 1.82580 to 1.82024, saving model to model_fer.h5
# 113/113 [==============================] - 23s 200ms/step - loss: 1.7970 - accuracy: 0.2569 - val_loss: 1.8202 - val_accuracy: 0.2449 - lr: 0.0010
# Epoch 5/200
# 113/113 [==============================] - ETA: 0s - loss: 1.7718 - accuracy: 0.2727
# Epoch 00005: val_loss did not improve from 1.82024
# 113/113 [==============================] - 23s 199ms/step - loss: 1.7718 - accuracy: 0.2727 - val_loss: 1.8212 - val_accuracy: 0.2583 - lr: 0.0010
# Epoch 6/200
# 113/113 [==============================] - ETA: 0s - loss: 1.7248 - accuracy: 0.2993
# Epoch 00006: val_loss improved from 1.82024 to 1.69919, saving model to model_fer.h5
# 113/113 [==============================] - 23s 202ms/step - loss: 1.7248 - accuracy: 0.2993 - val_loss: 1.6992 - val_accuracy: 0.2984 - lr: 0.0010
# Epoch 7/200
# 113/113 [==============================] - ETA: 0s - loss: 1.6634 - accuracy: 0.3287
# Epoch 00007: val_loss improved from 1.69919 to 1.62617, saving model to model_fer.h5
# 113/113 [==============================] - 23s 202ms/step - loss: 1.6634 - accuracy: 0.3287 - val_loss: 1.6262 - val_accuracy: 0.3650 - lr: 0.0010
# Epoch 8/200
# 113/113 [==============================] - ETA: 0s - loss: 1.6090 - accuracy: 0.3597
# Epoch 00008: val_loss improved from 1.62617 to 1.51085, saving model to model_fer.h5
# 113/113 [==============================] - 23s 202ms/step - loss: 1.6090 - accuracy: 0.3597 - val_loss: 1.5108 - val_accuracy: 0.4160 - lr: 0.0010
# Epoch 9/200
# 113/113 [==============================] - ETA: 0s - loss: 1.5488 - accuracy: 0.3909
# Epoch 00009: val_loss did not improve from 1.51085
# 113/113 [==============================] - 23s 201ms/step - loss: 1.5488 - accuracy: 0.3909 - val_loss: 1.6168 - val_accuracy: 0.3318 - lr: 0.0010
# Epoch 10/200
# 113/113 [==============================] - ETA: 0s - loss: 1.5032 - accuracy: 0.4106
# Epoch 00010: val_loss improved from 1.51085 to 1.46739, saving model to model_fer.h5
# 113/113 [==============================] - 23s 204ms/step - loss: 1.5032 - accuracy: 0.4106 - val_loss: 1.4674 - val_accuracy: 0.4271 - lr: 0.0010
# Epoch 11/200
# 113/113 [==============================] - ETA: 0s - loss: 1.4587 - accuracy: 0.4384
# Epoch 00011: val_loss did not improve from 1.46739
# 113/113 [==============================] - 23s 202ms/step - loss: 1.4587 - accuracy: 0.4384 - val_loss: 1.8130 - val_accuracy: 0.2549 - lr: 0.0010
# Epoch 12/200
# 113/113 [==============================] - ETA: 0s - loss: 1.4247 - accuracy: 0.4532
# Epoch 00012: val_loss improved from 1.46739 to 1.37875, saving model to model_fer.h5
# 113/113 [==============================] - 23s 204ms/step - loss: 1.4247 - accuracy: 0.4532 - val_loss: 1.3787 - val_accuracy: 0.4737 - lr: 0.0010
# Epoch 13/200
# 113/113 [==============================] - ETA: 0s - loss: 1.3966 - accuracy: 0.4714
# Epoch 00013: val_loss improved from 1.37875 to 1.32906, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.3966 - accuracy: 0.4714 - val_loss: 1.3291 - val_accuracy: 0.5091 - lr: 0.0010
# Epoch 14/200
# 113/113 [==============================] - ETA: 0s - loss: 1.3650 - accuracy: 0.4820
# Epoch 00014: val_loss did not improve from 1.32906
# 113/113 [==============================] - 23s 202ms/step - loss: 1.3650 - accuracy: 0.4820 - val_loss: 1.5569 - val_accuracy: 0.4115 - lr: 0.0010
# Epoch 15/200
# 113/113 [==============================] - ETA: 0s - loss: 1.3416 - accuracy: 0.4962
# Epoch 00015: val_loss improved from 1.32906 to 1.30017, saving model to model_fer.h5
# 113/113 [==============================] - 23s 204ms/step - loss: 1.3416 - accuracy: 0.4962 - val_loss: 1.3002 - val_accuracy: 0.5068 - lr: 0.0010
# Epoch 16/200
# 113/113 [==============================] - ETA: 0s - loss: 1.3091 - accuracy: 0.5086
# Epoch 00016: val_loss did not improve from 1.30017
# 113/113 [==============================] - 23s 203ms/step - loss: 1.3091 - accuracy: 0.5086 - val_loss: 1.3055 - val_accuracy: 0.5052 - lr: 0.0010
# Epoch 17/200
# 113/113 [==============================] - ETA: 0s - loss: 1.2978 - accuracy: 0.5174
# Epoch 00017: val_loss did not improve from 1.30017
# 113/113 [==============================] - 23s 202ms/step - loss: 1.2978 - accuracy: 0.5174 - val_loss: 1.3964 - val_accuracy: 0.4976 - lr: 0.0010
# Epoch 18/200
# 113/113 [==============================] - ETA: 0s - loss: 1.2833 - accuracy: 0.5228
# Epoch 00018: val_loss did not improve from 1.30017
# 113/113 [==============================] - 23s 202ms/step - loss: 1.2833 - accuracy: 0.5228 - val_loss: 1.3685 - val_accuracy: 0.4857 - lr: 0.0010
# Epoch 19/200
# 113/113 [==============================] - ETA: 0s - loss: 1.2564 - accuracy: 0.5348
# Epoch 00019: val_loss did not improve from 1.30017
# 113/113 [==============================] - 23s 203ms/step - loss: 1.2564 - accuracy: 0.5348 - val_loss: 1.3399 - val_accuracy: 0.4848 - lr: 0.0010
# Epoch 20/200
# 113/113 [==============================] - ETA: 0s - loss: 1.2443 - accuracy: 0.5419
# Epoch 00020: val_loss did not improve from 1.30017
# 113/113 [==============================] - 23s 203ms/step - loss: 1.2443 - accuracy: 0.5419 - val_loss: 1.4946 - val_accuracy: 0.4263 - lr: 0.0010
# Epoch 21/200
# 113/113 [==============================] - ETA: 0s - loss: 1.2364 - accuracy: 0.5426
# Epoch 00021: val_loss did not improve from 1.30017
# 113/113 [==============================] - 23s 203ms/step - loss: 1.2364 - accuracy: 0.5426 - val_loss: 1.3727 - val_accuracy: 0.4859 - lr: 0.0010
# Epoch 22/200
# 113/113 [==============================] - ETA: 0s - loss: 1.2123 - accuracy: 0.5555
# Epoch 00022: val_loss improved from 1.30017 to 1.24687, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.2123 - accuracy: 0.5555 - val_loss: 1.2469 - val_accuracy: 0.5350 - lr: 0.0010
# Epoch 23/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1954 - accuracy: 0.5605
# Epoch 00023: val_loss improved from 1.24687 to 1.21656, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.1954 - accuracy: 0.5605 - val_loss: 1.2166 - val_accuracy: 0.5489 - lr: 0.0010
# Epoch 24/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1890 - accuracy: 0.5642
# Epoch 00024: val_loss did not improve from 1.21656
# 113/113 [==============================] - 23s 203ms/step - loss: 1.1890 - accuracy: 0.5642 - val_loss: 1.4579 - val_accuracy: 0.4280 - lr: 0.0010
# Epoch 25/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1862 - accuracy: 0.5675
# Epoch 00025: val_loss did not improve from 1.21656
# 113/113 [==============================] - 23s 204ms/step - loss: 1.1862 - accuracy: 0.5675 - val_loss: 1.5360 - val_accuracy: 0.3976 - lr: 0.0010
# Epoch 26/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1839 - accuracy: 0.5699
# Epoch 00026: val_loss improved from 1.21656 to 1.10268, saving model to model_fer.h5
# 113/113 [==============================] - 23s 206ms/step - loss: 1.1839 - accuracy: 0.5699 - val_loss: 1.1027 - val_accuracy: 0.5913 - lr: 0.0010
# Epoch 27/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1562 - accuracy: 0.5781
# Epoch 00027: val_loss did not improve from 1.10268
# 113/113 [==============================] - 23s 204ms/step - loss: 1.1562 - accuracy: 0.5781 - val_loss: 1.1304 - val_accuracy: 0.5793 - lr: 0.0010
# Epoch 28/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1419 - accuracy: 0.5836
# Epoch 00028: val_loss improved from 1.10268 to 1.10016, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.1419 - accuracy: 0.5836 - val_loss: 1.1002 - val_accuracy: 0.5929 - lr: 0.0010
# Epoch 29/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1335 - accuracy: 0.5857
# Epoch 00029: val_loss did not improve from 1.10016
# 113/113 [==============================] - 23s 203ms/step - loss: 1.1335 - accuracy: 0.5857 - val_loss: 1.1580 - val_accuracy: 0.5834 - lr: 0.0010
# Epoch 30/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1316 - accuracy: 0.5890
# Epoch 00030: val_loss did not improve from 1.10016
# 113/113 [==============================] - 23s 203ms/step - loss: 1.1316 - accuracy: 0.5890 - val_loss: 1.1095 - val_accuracy: 0.5874 - lr: 0.0010
# Epoch 31/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1106 - accuracy: 0.5943
# Epoch 00031: val_loss improved from 1.10016 to 1.08246, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.1106 - accuracy: 0.5943 - val_loss: 1.0825 - val_accuracy: 0.6018 - lr: 0.0010
# Epoch 32/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1044 - accuracy: 0.5965
# Epoch 00032: val_loss did not improve from 1.08246
# 113/113 [==============================] - 23s 203ms/step - loss: 1.1044 - accuracy: 0.5965 - val_loss: 1.1961 - val_accuracy: 0.5550 - lr: 0.0010
# Epoch 33/200
# 113/113 [==============================] - ETA: 0s - loss: 1.1070 - accuracy: 0.5978
# Epoch 00033: val_loss did not improve from 1.08246
# 113/113 [==============================] - 23s 203ms/step - loss: 1.1070 - accuracy: 0.5978 - val_loss: 1.0852 - val_accuracy: 0.5965 - lr: 0.0010
# Epoch 34/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0871 - accuracy: 0.6016
# Epoch 00034: val_loss did not improve from 1.08246
# 113/113 [==============================] - 23s 203ms/step - loss: 1.0871 - accuracy: 0.6016 - val_loss: 1.1322 - val_accuracy: 0.5890 - lr: 0.0010
# Epoch 35/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0796 - accuracy: 0.6121
# Epoch 00035: val_loss improved from 1.08246 to 1.07080, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.0796 - accuracy: 0.6121 - val_loss: 1.0708 - val_accuracy: 0.6027 - lr: 0.0010
# Epoch 36/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0720 - accuracy: 0.6121
# Epoch 00036: val_loss improved from 1.07080 to 1.05989, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.0720 - accuracy: 0.6121 - val_loss: 1.0599 - val_accuracy: 0.6172 - lr: 0.0010
# Epoch 37/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0592 - accuracy: 0.6128
# Epoch 00037: val_loss improved from 1.05989 to 1.04389, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.0592 - accuracy: 0.6128 - val_loss: 1.0439 - val_accuracy: 0.6141 - lr: 0.0010
# Epoch 38/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0530 - accuracy: 0.6185
# Epoch 00038: val_loss improved from 1.04389 to 0.98907, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 1.0530 - accuracy: 0.6185 - val_loss: 0.9891 - val_accuracy: 0.6322 - lr: 0.0010
# Epoch 39/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0402 - accuracy: 0.6217
# Epoch 00039: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 203ms/step - loss: 1.0402 - accuracy: 0.6217 - val_loss: 1.1255 - val_accuracy: 0.5818 - lr: 0.0010
# Epoch 40/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0356 - accuracy: 0.6216
# Epoch 00040: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 204ms/step - loss: 1.0356 - accuracy: 0.6216 - val_loss: 1.0994 - val_accuracy: 0.5929 - lr: 0.0010
# Epoch 41/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0231 - accuracy: 0.6283
# Epoch 00041: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 203ms/step - loss: 1.0231 - accuracy: 0.6283 - val_loss: 1.1347 - val_accuracy: 0.5834 - lr: 0.0010
# Epoch 42/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0183 - accuracy: 0.6304
# Epoch 00042: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 203ms/step - loss: 1.0183 - accuracy: 0.6304 - val_loss: 1.1510 - val_accuracy: 0.5823 - lr: 0.0010
# Epoch 43/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0171 - accuracy: 0.6320
# Epoch 00043: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 203ms/step - loss: 1.0171 - accuracy: 0.6320 - val_loss: 1.3314 - val_accuracy: 0.5068 - lr: 0.0010
# Epoch 44/200
# 113/113 [==============================] - ETA: 0s - loss: 1.0033 - accuracy: 0.6338
# Epoch 00044: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 203ms/step - loss: 1.0033 - accuracy: 0.6338 - val_loss: 1.0758 - val_accuracy: 0.5971 - lr: 0.0010
# Epoch 45/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9973 - accuracy: 0.6379
# Epoch 00045: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9973 - accuracy: 0.6379 - val_loss: 1.0260 - val_accuracy: 0.6213 - lr: 0.0010
# Epoch 46/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9934 - accuracy: 0.6404
# Epoch 00046: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9934 - accuracy: 0.6404 - val_loss: 1.0315 - val_accuracy: 0.6158 - lr: 0.0010
# Epoch 47/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9833 - accuracy: 0.6437
# Epoch 00047: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9833 - accuracy: 0.6437 - val_loss: 1.0269 - val_accuracy: 0.6233 - lr: 0.0010
# Epoch 48/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9746 - accuracy: 0.6481
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
#
# Epoch 00048: val_loss did not improve from 0.98907
# 113/113 [==============================] - 23s 204ms/step - loss: 0.9746 - accuracy: 0.6481 - val_loss: 0.9982 - val_accuracy: 0.6314 - lr: 0.0010
# Epoch 49/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9487 - accuracy: 0.6546
# Epoch 00049: val_loss improved from 0.98907 to 0.96915, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.9487 - accuracy: 0.6546 - val_loss: 0.9691 - val_accuracy: 0.6478 - lr: 7.0000e-04
# Epoch 50/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9442 - accuracy: 0.6573
# Epoch 00050: val_loss did not improve from 0.96915
# 113/113 [==============================] - 23s 202ms/step - loss: 0.9442 - accuracy: 0.6573 - val_loss: 1.0969 - val_accuracy: 0.5901 - lr: 7.0000e-04
# Epoch 51/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9337 - accuracy: 0.6628
# Epoch 00051: val_loss improved from 0.96915 to 0.96419, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.9337 - accuracy: 0.6628 - val_loss: 0.9642 - val_accuracy: 0.6328 - lr: 7.0000e-04
# Epoch 52/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9215 - accuracy: 0.6695
# Epoch 00052: val_loss improved from 0.96419 to 0.95185, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.9215 - accuracy: 0.6695 - val_loss: 0.9518 - val_accuracy: 0.6489 - lr: 7.0000e-04
# Epoch 53/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9173 - accuracy: 0.6672
# Epoch 00053: val_loss improved from 0.95185 to 0.93848, saving model to model_fer.h5
# 113/113 [==============================] - 23s 206ms/step - loss: 0.9173 - accuracy: 0.6672 - val_loss: 0.9385 - val_accuracy: 0.6520 - lr: 7.0000e-04
# Epoch 54/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9298 - accuracy: 0.6616
# Epoch 00054: val_loss did not improve from 0.93848
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9298 - accuracy: 0.6616 - val_loss: 1.4240 - val_accuracy: 0.4628 - lr: 7.0000e-04
# Epoch 55/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9305 - accuracy: 0.6601
# Epoch 00055: val_loss did not improve from 0.93848
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9305 - accuracy: 0.6601 - val_loss: 1.0250 - val_accuracy: 0.6160 - lr: 7.0000e-04
# Epoch 56/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9183 - accuracy: 0.6658
# Epoch 00056: val_loss improved from 0.93848 to 0.92618, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.9183 - accuracy: 0.6658 - val_loss: 0.9262 - val_accuracy: 0.6567 - lr: 7.0000e-04
# Epoch 57/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9346 - accuracy: 0.6632
# Epoch 00057: val_loss did not improve from 0.92618
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9346 - accuracy: 0.6632 - val_loss: 0.9816 - val_accuracy: 0.6425 - lr: 7.0000e-04
# Epoch 58/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9153 - accuracy: 0.6683
# Epoch 00058: val_loss did not improve from 0.92618
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9153 - accuracy: 0.6683 - val_loss: 0.9594 - val_accuracy: 0.6495 - lr: 7.0000e-04
# Epoch 59/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9094 - accuracy: 0.6724
# Epoch 00059: val_loss did not improve from 0.92618
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9094 - accuracy: 0.6724 - val_loss: 0.9270 - val_accuracy: 0.6545 - lr: 7.0000e-04
# Epoch 60/200
# 113/113 [==============================] - ETA: 0s - loss: 0.9065 - accuracy: 0.6739
# Epoch 00060: val_loss did not improve from 0.92618
# 113/113 [==============================] - 23s 203ms/step - loss: 0.9065 - accuracy: 0.6739 - val_loss: 0.9623 - val_accuracy: 0.6434 - lr: 7.0000e-04
# Epoch 61/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8898 - accuracy: 0.6799
# Epoch 00061: val_loss improved from 0.92618 to 0.91404, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.8898 - accuracy: 0.6799 - val_loss: 0.9140 - val_accuracy: 0.6640 - lr: 7.0000e-04
# Epoch 62/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8879 - accuracy: 0.6792
# Epoch 00062: val_loss did not improve from 0.91404
# 113/113 [==============================] - 23s 204ms/step - loss: 0.8879 - accuracy: 0.6792 - val_loss: 0.9172 - val_accuracy: 0.6615 - lr: 7.0000e-04
# Epoch 63/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8874 - accuracy: 0.6808
# Epoch 00063: val_loss did not improve from 0.91404
# 113/113 [==============================] - 23s 202ms/step - loss: 0.8874 - accuracy: 0.6808 - val_loss: 1.0371 - val_accuracy: 0.6094 - lr: 7.0000e-04
# Epoch 64/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8719 - accuracy: 0.6853
# Epoch 00064: val_loss did not improve from 0.91404
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8719 - accuracy: 0.6853 - val_loss: 0.9545 - val_accuracy: 0.6425 - lr: 7.0000e-04
# Epoch 65/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8677 - accuracy: 0.6891
# Epoch 00065: val_loss improved from 0.91404 to 0.90696, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.8677 - accuracy: 0.6891 - val_loss: 0.9070 - val_accuracy: 0.6606 - lr: 7.0000e-04
# Epoch 66/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8583 - accuracy: 0.6908
# Epoch 00066: val_loss did not improve from 0.90696
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8583 - accuracy: 0.6908 - val_loss: 1.0188 - val_accuracy: 0.6361 - lr: 7.0000e-04
# Epoch 67/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8538 - accuracy: 0.6915
# Epoch 00067: val_loss did not improve from 0.90696
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8538 - accuracy: 0.6915 - val_loss: 0.9574 - val_accuracy: 0.6503 - lr: 7.0000e-04
# Epoch 68/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8555 - accuracy: 0.6922
# Epoch 00068: val_loss improved from 0.90696 to 0.90548, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.8555 - accuracy: 0.6922 - val_loss: 0.9055 - val_accuracy: 0.6676 - lr: 7.0000e-04
# Epoch 69/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8482 - accuracy: 0.6956
# Epoch 00069: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8482 - accuracy: 0.6956 - val_loss: 0.9423 - val_accuracy: 0.6542 - lr: 7.0000e-04
# Epoch 70/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8441 - accuracy: 0.6971
# Epoch 00070: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 202ms/step - loss: 0.8441 - accuracy: 0.6971 - val_loss: 0.9315 - val_accuracy: 0.6498 - lr: 7.0000e-04
# Epoch 71/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8417 - accuracy: 0.6988
# Epoch 00071: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8417 - accuracy: 0.6988 - val_loss: 1.1885 - val_accuracy: 0.5907 - lr: 7.0000e-04
# Epoch 72/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8399 - accuracy: 0.6952
# Epoch 00072: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8399 - accuracy: 0.6952 - val_loss: 0.9305 - val_accuracy: 0.6576 - lr: 7.0000e-04
# Epoch 73/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8391 - accuracy: 0.6979
# Epoch 00073: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8391 - accuracy: 0.6979 - val_loss: 0.9468 - val_accuracy: 0.6461 - lr: 7.0000e-04
# Epoch 74/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8230 - accuracy: 0.7031
# Epoch 00074: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 202ms/step - loss: 0.8230 - accuracy: 0.7031 - val_loss: 0.9695 - val_accuracy: 0.6389 - lr: 7.0000e-04
# Epoch 75/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8197 - accuracy: 0.7007
# Epoch 00075: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8197 - accuracy: 0.7007 - val_loss: 0.9141 - val_accuracy: 0.6612 - lr: 7.0000e-04
# Epoch 76/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8235 - accuracy: 0.7013
# Epoch 00076: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8235 - accuracy: 0.7013 - val_loss: 1.0569 - val_accuracy: 0.6110 - lr: 7.0000e-04
# Epoch 77/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8855 - accuracy: 0.6787
# Epoch 00077: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8855 - accuracy: 0.6787 - val_loss: 1.0048 - val_accuracy: 0.6381 - lr: 7.0000e-04
# Epoch 78/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8497 - accuracy: 0.6954
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 0.0004900000232737511.
#
# Epoch 00078: val_loss did not improve from 0.90548
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8497 - accuracy: 0.6954 - val_loss: 1.0068 - val_accuracy: 0.6286 - lr: 7.0000e-04
# Epoch 79/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8168 - accuracy: 0.7056
# Epoch 00079: val_loss improved from 0.90548 to 0.90009, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.8168 - accuracy: 0.7056 - val_loss: 0.9001 - val_accuracy: 0.6712 - lr: 4.9000e-04
# Epoch 80/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8133 - accuracy: 0.7090
# Epoch 00080: val_loss did not improve from 0.90009
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8133 - accuracy: 0.7090 - val_loss: 0.9579 - val_accuracy: 0.6495 - lr: 4.9000e-04
# Epoch 81/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8013 - accuracy: 0.7104
# Epoch 00081: val_loss did not improve from 0.90009
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8013 - accuracy: 0.7104 - val_loss: 0.9015 - val_accuracy: 0.6682 - lr: 4.9000e-04
# Epoch 82/200
# 112/113 [============================>.] - ETA: 0s - loss: 0.7890 - accuracy: 0.7156
# Epoch 00082: val_loss improved from 0.90009 to 0.87089, saving model to model_fer.h5
# 113/113 [==============================] - 23s 204ms/step - loss: 0.7888 - accuracy: 0.7157 - val_loss: 0.8709 - val_accuracy: 0.6860 - lr: 4.9000e-04
# Epoch 83/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7815 - accuracy: 0.7195
# Epoch 00083: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7815 - accuracy: 0.7195 - val_loss: 0.9781 - val_accuracy: 0.6537 - lr: 4.9000e-04
# Epoch 84/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7780 - accuracy: 0.7196
# Epoch 00084: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7780 - accuracy: 0.7196 - val_loss: 0.9099 - val_accuracy: 0.6718 - lr: 4.9000e-04
# Epoch 85/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8117 - accuracy: 0.7087
# Epoch 00085: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.8117 - accuracy: 0.7087 - val_loss: 0.8964 - val_accuracy: 0.6768 - lr: 4.9000e-04
# Epoch 86/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7846 - accuracy: 0.7173
# Epoch 00086: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7846 - accuracy: 0.7173 - val_loss: 0.9559 - val_accuracy: 0.6531 - lr: 4.9000e-04
# Epoch 87/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7762 - accuracy: 0.7187
# Epoch 00087: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7762 - accuracy: 0.7187 - val_loss: 0.9197 - val_accuracy: 0.6765 - lr: 4.9000e-04
# Epoch 88/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7667 - accuracy: 0.7237
# Epoch 00088: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7667 - accuracy: 0.7237 - val_loss: 0.8931 - val_accuracy: 0.6773 - lr: 4.9000e-04
# Epoch 89/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7692 - accuracy: 0.7209
# Epoch 00089: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7692 - accuracy: 0.7209 - val_loss: 2.6633 - val_accuracy: 0.3001 - lr: 4.9000e-04
# Epoch 90/200
# 113/113 [==============================] - ETA: 0s - loss: 0.8688 - accuracy: 0.6869
# Epoch 00090: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 202ms/step - loss: 0.8688 - accuracy: 0.6869 - val_loss: 0.9341 - val_accuracy: 0.6598 - lr: 4.9000e-04
# Epoch 91/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7869 - accuracy: 0.7176
# Epoch 00091: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 202ms/step - loss: 0.7869 - accuracy: 0.7176 - val_loss: 0.8932 - val_accuracy: 0.6787 - lr: 4.9000e-04
# Epoch 92/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7882 - accuracy: 0.7164
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 0.00034300000406801696.
#
# Epoch 00092: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7882 - accuracy: 0.7164 - val_loss: 0.8736 - val_accuracy: 0.6840 - lr: 4.9000e-04
# Epoch 93/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7662 - accuracy: 0.7253
# Epoch 00093: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7662 - accuracy: 0.7253 - val_loss: 0.8783 - val_accuracy: 0.6835 - lr: 3.4300e-04
# Epoch 94/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7569 - accuracy: 0.7277
# Epoch 00094: val_loss did not improve from 0.87089
# 113/113 [==============================] - 23s 202ms/step - loss: 0.7569 - accuracy: 0.7277 - val_loss: 0.8758 - val_accuracy: 0.6946 - lr: 3.4300e-04
# Epoch 95/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7458 - accuracy: 0.7316
# Epoch 00095: val_loss improved from 0.87089 to 0.86961, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.7458 - accuracy: 0.7316 - val_loss: 0.8696 - val_accuracy: 0.6818 - lr: 3.4300e-04
# Epoch 96/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7441 - accuracy: 0.7314
# Epoch 00096: val_loss improved from 0.86961 to 0.86391, saving model to model_fer.h5
# 113/113 [==============================] - 23s 205ms/step - loss: 0.7441 - accuracy: 0.7314 - val_loss: 0.8639 - val_accuracy: 0.6893 - lr: 3.4300e-04
# Epoch 97/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7376 - accuracy: 0.7359
# Epoch 00097: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7376 - accuracy: 0.7359 - val_loss: 0.8687 - val_accuracy: 0.6857 - lr: 3.4300e-04
# Epoch 98/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7334 - accuracy: 0.7348
# Epoch 00098: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7334 - accuracy: 0.7348 - val_loss: 0.8926 - val_accuracy: 0.6740 - lr: 3.4300e-04
# Epoch 99/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7361 - accuracy: 0.7377
# Epoch 00099: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7361 - accuracy: 0.7377 - val_loss: 0.9285 - val_accuracy: 0.6640 - lr: 3.4300e-04
# Epoch 100/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7288 - accuracy: 0.7372
# Epoch 00100: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7288 - accuracy: 0.7372 - val_loss: 0.8973 - val_accuracy: 0.6746 - lr: 3.4300e-04
# Epoch 101/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7439 - accuracy: 0.7350
# Epoch 00101: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 202ms/step - loss: 0.7439 - accuracy: 0.7350 - val_loss: 0.8869 - val_accuracy: 0.6807 - lr: 3.4300e-04
# Epoch 102/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7282 - accuracy: 0.7384
# Epoch 00102: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7282 - accuracy: 0.7384 - val_loss: 0.8924 - val_accuracy: 0.6840 - lr: 3.4300e-04
# Epoch 103/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7197 - accuracy: 0.7392
# Epoch 00103: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 202ms/step - loss: 0.7197 - accuracy: 0.7392 - val_loss: 0.8941 - val_accuracy: 0.6796 - lr: 3.4300e-04
# Epoch 104/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7181 - accuracy: 0.7410
# Epoch 00104: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7181 - accuracy: 0.7410 - val_loss: 0.9130 - val_accuracy: 0.6715 - lr: 3.4300e-04
# Epoch 105/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7124 - accuracy: 0.7410
# Epoch 00105: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7124 - accuracy: 0.7410 - val_loss: 0.8675 - val_accuracy: 0.6938 - lr: 3.4300e-04
# Epoch 106/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7046 - accuracy: 0.7466
# Epoch 00106: ReduceLROnPlateau reducing learning rate to 0.00024009999469853935.
#
# Epoch 00106: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7046 - accuracy: 0.7466 - val_loss: 0.9252 - val_accuracy: 0.6707 - lr: 3.4300e-04
# Epoch 107/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6959 - accuracy: 0.7499
# Epoch 00107: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6959 - accuracy: 0.7499 - val_loss: 0.8920 - val_accuracy: 0.6810 - lr: 2.4010e-04
# Epoch 108/200
# 113/113 [==============================] - ETA: 0s - loss: 0.7003 - accuracy: 0.7497
# Epoch 00108: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.7003 - accuracy: 0.7497 - val_loss: 0.9207 - val_accuracy: 0.6684 - lr: 2.4010e-04
# Epoch 109/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.7499
# Epoch 00109: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6925 - accuracy: 0.7499 - val_loss: 0.8900 - val_accuracy: 0.6871 - lr: 2.4010e-04
# Epoch 110/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6808 - accuracy: 0.7544
# Epoch 00110: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 202ms/step - loss: 0.6808 - accuracy: 0.7544 - val_loss: 0.9087 - val_accuracy: 0.6821 - lr: 2.4010e-04
# Epoch 111/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6866 - accuracy: 0.7508
# Epoch 00111: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 202ms/step - loss: 0.6866 - accuracy: 0.7508 - val_loss: 0.8768 - val_accuracy: 0.6966 - lr: 2.4010e-04
# Epoch 112/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6861 - accuracy: 0.7532
# Epoch 00112: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6861 - accuracy: 0.7532 - val_loss: 0.8792 - val_accuracy: 0.6916 - lr: 2.4010e-04
# Epoch 113/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6826 - accuracy: 0.7577
# Epoch 00113: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6826 - accuracy: 0.7577 - val_loss: 0.8736 - val_accuracy: 0.6902 - lr: 2.4010e-04
# Epoch 114/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6791 - accuracy: 0.7569
# Epoch 00114: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6791 - accuracy: 0.7569 - val_loss: 0.9220 - val_accuracy: 0.6762 - lr: 2.4010e-04
# Epoch 115/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6769 - accuracy: 0.7569
# Epoch 00115: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6769 - accuracy: 0.7569 - val_loss: 0.8917 - val_accuracy: 0.6885 - lr: 2.4010e-04
# Epoch 116/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6725 - accuracy: 0.7585
# Epoch 00116: ReduceLROnPlateau reducing learning rate to 0.00016806999628897755.
#
# Epoch 00116: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 205ms/step - loss: 0.6725 - accuracy: 0.7585 - val_loss: 0.8736 - val_accuracy: 0.6924 - lr: 2.4010e-04
# Epoch 117/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6886 - accuracy: 0.7534
# Epoch 00117: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6886 - accuracy: 0.7534 - val_loss: 0.9144 - val_accuracy: 0.6840 - lr: 1.6807e-04
# Epoch 118/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6753 - accuracy: 0.7582
# Epoch 00118: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6753 - accuracy: 0.7582 - val_loss: 0.8882 - val_accuracy: 0.6952 - lr: 1.6807e-04
# Epoch 119/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6660 - accuracy: 0.7607
# Epoch 00119: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6660 - accuracy: 0.7607 - val_loss: 0.8755 - val_accuracy: 0.6969 - lr: 1.6807e-04
# Epoch 120/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6581 - accuracy: 0.7636
# Epoch 00120: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6581 - accuracy: 0.7636 - val_loss: 0.8870 - val_accuracy: 0.6935 - lr: 1.6807e-04
# Epoch 121/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6642 - accuracy: 0.7609
# Epoch 00121: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6642 - accuracy: 0.7609 - val_loss: 0.8860 - val_accuracy: 0.6893 - lr: 1.6807e-04
# Epoch 122/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6525 - accuracy: 0.7664
# Epoch 00122: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6525 - accuracy: 0.7664 - val_loss: 0.9092 - val_accuracy: 0.6899 - lr: 1.6807e-04
# Epoch 123/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6581 - accuracy: 0.7632
# Epoch 00123: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6581 - accuracy: 0.7632 - val_loss: 0.9176 - val_accuracy: 0.6824 - lr: 1.6807e-04
# Epoch 124/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6583 - accuracy: 0.7617
# Epoch 00124: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6583 - accuracy: 0.7617 - val_loss: 0.8829 - val_accuracy: 0.6949 - lr: 1.6807e-04
# Epoch 125/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6470 - accuracy: 0.7667
# Epoch 00125: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 204ms/step - loss: 0.6470 - accuracy: 0.7667 - val_loss: 0.8838 - val_accuracy: 0.6882 - lr: 1.6807e-04
# Epoch 126/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6511 - accuracy: 0.7664
# Epoch 00126: ReduceLROnPlateau reducing learning rate to 0.00011764899536501615.
#
# Epoch 00126: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6511 - accuracy: 0.7664 - val_loss: 0.8838 - val_accuracy: 0.6946 - lr: 1.6807e-04
# Epoch 127/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6521 - accuracy: 0.7657
# Epoch 00127: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6521 - accuracy: 0.7657 - val_loss: 0.8798 - val_accuracy: 0.6980 - lr: 1.1765e-04
# Epoch 128/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6421 - accuracy: 0.7685
# Epoch 00128: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6421 - accuracy: 0.7685 - val_loss: 0.8943 - val_accuracy: 0.6938 - lr: 1.1765e-04
# Epoch 129/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6514 - accuracy: 0.7675
# Epoch 00129: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6514 - accuracy: 0.7675 - val_loss: 0.8785 - val_accuracy: 0.6946 - lr: 1.1765e-04
# Epoch 130/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6452 - accuracy: 0.7660
# Epoch 00130: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6452 - accuracy: 0.7660 - val_loss: 0.8801 - val_accuracy: 0.6988 - lr: 1.1765e-04
# Epoch 131/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6474 - accuracy: 0.7661
# Epoch 00131: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6474 - accuracy: 0.7661 - val_loss: 0.8835 - val_accuracy: 0.6955 - lr: 1.1765e-04
# Epoch 132/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6366 - accuracy: 0.7675
# Epoch 00132: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6366 - accuracy: 0.7675 - val_loss: 0.9061 - val_accuracy: 0.6966 - lr: 1.1765e-04
# Epoch 133/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6349 - accuracy: 0.7721
# Epoch 00133: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6349 - accuracy: 0.7721 - val_loss: 0.9005 - val_accuracy: 0.6943 - lr: 1.1765e-04
# Epoch 134/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6483 - accuracy: 0.7682
# Epoch 00134: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6483 - accuracy: 0.7682 - val_loss: 0.8713 - val_accuracy: 0.7019 - lr: 1.1765e-04
# Epoch 135/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.7737
# Epoch 00135: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6331 - accuracy: 0.7737 - val_loss: 0.9262 - val_accuracy: 0.6846 - lr: 1.1765e-04
# Epoch 136/200
# 113/113 [==============================] - ETA: 0s - loss: 0.6277 - accuracy: 0.7754
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 8.235429777414538e-05.
#
# Epoch 00136: val_loss did not improve from 0.86391
# 113/113 [==============================] - 23s 203ms/step - loss: 0.6277 - accuracy: 0.7754 - val_loss: 0.8864 - val_accuracy: 0.6949 - lr: 1.1765e-04
# Epoch 00136: early stopping

# %%
# Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=2.0)
plt.plot(history.history['val_loss'],'b',linewidth=2.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)
 
# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=2.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=2.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
def detect_face(image):
  cascPath = '/content/drive/My Drive/BE Project/sarvesh/haarcascades/haarcascade_frontalface_default.xml'
  faceCascade = cv2.CascadeClassifier(cascPath)
  #BGR to gray conversion
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  #Cascade multiscale classifier
  detected_faces = faceCascade.detectMultiScale(image, minNeighbors=3,
                                                minSize=(10,10)
  )
  sub = gray

  for x, y, w, h in detected_faces:
    #if w>100:
      sub = gray[y:y+h,x:x+w]
  return sub,detected_faces

# %%
from google.colab.patches import cv2_imshow

# %%
image = cv2.imread('/content/drive/My Drive/Datasets/sample_images/person_su3.jpg',1)
cv2_imshow(image)
print(image.shape)
sub_img2,detected_face = detect_face(image)
print(sub_img2.shape)
cv2_imshow(sub_img2)
sub_img = cv2.resize(sub_img2, (48,48), interpolation = cv2.INTER_AREA)
sub_img = sub_img/255
#cv2_imshow(sub_img)
print(sub_img.shape)
sub_img = np.reshape(sub_img, (1,48,48,1))
print(sub_img.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F8B0E139AC8>
# (183, 275, 3)
# (99, 99)
# <PIL.Image.Image image mode=L size=99x99 at 0x7F8B0E1399E8>
# (48, 48)
# (1, 48, 48, 1)

# %%
pred_array = model.predict(sub_img)
print(pred_array)
pred_array_new= np.squeeze(pred_array)
prediction = np.argmax(pred_array_new)
print(pred_array_new)
print(prediction)
print(get_label(prediction))
# Out:
# [[6.2136864e-03 1.7378856e-04 3.5796577e-01 7.6107755e-03 4.2072362e-03
#   6.2230420e-01 1.5245653e-03]]
# [6.2136864e-03 1.7378856e-04 3.5796577e-01 7.6107755e-03 4.2072362e-03
#  6.2230420e-01 1.5245653e-03]
# 5
# Surprise

# %%
score = model.evaluate(test_data,y_test,steps=100)
# Out:
# 100/100 [==============================] - 2s 15ms/step - loss: 0.9272 - accuracy: 0.6771

# %%
Y_pred = model.predict(test_data)

# %%
y_pred = np.argmax(Y_pred, axis=1)
y_pred
# Out:
# array([4, 1, 0, ..., 4, 4, 6])

# %%
y_test_new = np.argmax(y_test, axis=1)
print(y_test_new)
print(y_test_new.shape)
# Out:
# [0 1 4 ... 4 4 4]
# (3589,)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt

# %%
print('Confusion Matrix')
cnf=confusion_matrix(y_test_new, y_pred)
print(cnf)
print('Classification Report')
target_names = ['Angry', 'Disgust', 'Fear','Happy','Sad','Surprise','Neutral']
clf=classification_report(y_test_new, y_pred, target_names=target_names)
# Out:
# Confusion Matrix
# [[281   7  47  21  51  12  48]
#  [ 15  31   2   2   3   1   2]
#  [ 48   0 232  11 108  34  63]
#  [ 10   0  18 775   9  21  62]
#  [ 62   2  64  21 367   9 128]
#  [ 12   0  44  13   3 331  12]
#  [ 39   0  25  45  77   8 413]]
# Classification Report

# %%
fig, ax = plot_confusion_matrix(conf_mat=cnf,
                                colorbar=True,
                                show_absolute=True,
                                show_normed=False,figsize=(10,10),cmap='GnBu')
ax.set_xticklabels([''] + list(np.unique(target_names)))
ax.set_yticklabels([''] + list(np.unique(target_names)))

plt.show()
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#        Angry       0.60      0.60      0.60       467
#      Disgust       0.78      0.55      0.65        56
#         Fear       0.54      0.47      0.50       496
#        Happy       0.87      0.87      0.87       895
#          Sad       0.59      0.56      0.58       653
#     Surprise       0.80      0.80      0.80       415
#      Neutral       0.57      0.68      0.62       607
#
#     accuracy                           0.68      3589
#    macro avg       0.68      0.65      0.66      3589
# weighted avg       0.68      0.68      0.68      3589
